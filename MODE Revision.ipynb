# %%
#MODE  - 9-12-25

# given is the dataset as a list of integers where some integers are repeated
# for each iteration in for loop print the number of times is seen and store this information in K:V format

# %%
data = [2,5,5,5,6,6,7]
freq = {} #empty dictionary
for x in data:
    freq[x] = freq.get(x,0) +1
    print(freq)

max_freq = max(freq.values())
print(max_freq)
# Out:
# {2: 1}
# {2: 1, 5: 1}
# {2: 1, 5: 2}
# {2: 1, 5: 3}
# {2: 1, 5: 3, 6: 1}
# {2: 1, 5: 3, 6: 2}
# {2: 1, 5: 3, 6: 2, 7: 1}
# 3

# %%
data = [12,12,15,15,25,25, 36,36,47,57,47]
freq = {} #empty dictionary
for x in data:
    freq[x] = freq.get(x,0) +1
    print(freq)

# %%
#10-12-25

data=[2,5,5,5,6,6,7,7,7,7]
freq={}
for x in data:
    freq[x] = freq.get(x,0) +1
    print(freq)
max_freq = max(freq.values())

print("Maximum freq = ", max_freq)

# %%
#11-12-25


data = [12,12,15,15,25,25,36,36,36,36,47,57,57]
freq={}
for x in data:
    freq[x] = freq.get(x,0) + 1
    print(freq)

# %%
data = [12,12,15,15,25,25,36,36,36,36,47,57,57]
freq={}
for x in data:
    freq[x] = freq.get(x,0) +1
    print(freq)
max_freq = max(freq.values())

print("Maximum freq = ", max_freq)

# %%
d = [12,12,15,15,25,25,36,36,36,47,57]
freq={}
for x in d:
    freq [x] = freq.get(x,0) + 1
    print(freq)

# %%
y = max(freq.values())
print(y)
# Out:
# 2

# %%
data = [1,2,2,3,3,4]
freq={}
for x in data:
    freq[x] = freq.get(x,0) +1
    print(freq)
print(freq)
max_freq = max(freq.values())
print(max_freq)
# Out:
# {1: 1}
# {1: 1, 2: 1}
# {1: 1, 2: 2}
# {1: 1, 2: 2, 3: 1}
# {1: 1, 2: 2, 3: 2}
# {1: 1, 2: 2, 3: 2, 4: 1}
# {1: 1, 2: 2, 3: 2, 4: 1}
# 2
