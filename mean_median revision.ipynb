# %%
l=[1,2,3,4]
sum_of_list=sum(l)
count=len(l)
print("sum", sum_of_list)
print("count", count)
# Out:
# sum 10
# count 4

# %%
M=[14,42,17,19]
sum_of_M=sum(M)
count_of_M=len(M)
print("sum_of_M=", sum_of_M)
print("count_of_M=", count_of_M)

# %%
M=[14,42,17,19,67,90,45,20]
sum_of_M=sum(M)
count_of_M=len(M)
print("sum_of_M=", sum_of_M)
print("count_of_M=", count_of_M)

# %%
M=[14,42,17,19,67,90,45,20]
sum_of_M=sum(M)
count_of_M=len(M)
mean=sum_of_M/count_of_M
print("mean=", mean)
print("count_of_M=", count_of_M)
print("sum_of_M=", sum_of_M)

# %%
Q=[24,19,18,17,34,71]
sum_of_Q=sum(Q)
count_of_Q=len(Q)
mean=sum_of_Q/count_of_Q
print("mean=", mean)
print("count_of_Q=", count_of_Q)
print("sum_of_Q=", sum_of_Q)

# %%
S=[3,6,4,8]
sum=sum(S)
print("the sum is",sum)

# %%
S=[3,6,4,8]
sum_of_list=sum(S)
count=len(S)
print("sum", sum_of_list)
print("count", count)

# %%
S=[3,6,4,8]
sum_of_S=sum(S)
count_of_S=len(S)
mean=sum_of_S/count_of_S
print("mean=", mean)
print("count_of_S=", count_of_S)
print("sum_of_S =", sum_of_S)

# %%
F=[3,6,4,8]
sum_of_F=sum(F)
count_of_F=len(F)
mean=sum_of_F/count_of_F
print("sum", sum_of_list)
print("count", count)
print("mean", mean)

# %%
## 24-11-25

T=[12,14,15,16,18,19,20,22,24,27,36,78]
print(T[0])

# %%
#B.

n=len(T)
if n%2 == 0:
   midpos1 = n//2-1
   midpos2 = n//2
   print(midpos1,midpos2)
else:
    midpos = n//2
    print(midpos)

# %%
U=[12,14,15,16,18,19,20,22,24,27,36,78,79,80,81]
U.sort()
print(U[0:])
n = len(U)
if n%2 == 0:
    median = (U[n//2])+([n//2-1])/2

else:
    median = (U[n//2])
print(median)
print(f"med {U[n//2]} , {U[n//2-1]}")

# %%
#26-11-25

#a. Print the value of V(0),V(1),V(2),V(3)...
#b. Print the index of mid position of this list
#c. Print the value at index of mid position of this list

V=[12,14,15,16,18,19,20,22,24,27,36,78,79,80,81,82,87,89,90,95,98]
V.sort()
n=len(V)
print(V[0:])
if n%2 == 0:
    midpos1 = n//2-1
    midpos2 = n//2
    print(midpose1)
    print(midpose2)
    print((midpose1),(midpose2))

else:
   midpose = n//2
print(midpose)

# %%
#Solution

n=len(V)
if n%2 == 0:
    midpos1 = n//2-1
    midpos2 = n//2
    print(midpos1,midpos2)
    print(V[midpos1],V[midpos2])

else:
    midpos = n//2
    print(midpos)
    print(V[midpos])

# %%
#2nd question

#a. print the value of W[0],W[1],W[2],W[3]...
#b. Print the index of mid position of this list
#c. Print the value at index of mid position of this list

W=[2,4,5,6,8,9,10,24,27,36,48,59,80,81,82,87,89,90,95,98,109,110,111,116,118,119,227,228,229,230,235]
W.sort()
n=len(W)



# W= [2,4,5,6,8,9,10,22] - DATE - 27-11-25
# print the index of mid position of this list
# print the value of index of mid position of this list
# find out the median of dataset W


W= [2,4,5,6,8,9,10,22]
W.sort()
n=len(W)
if n%2== 0:
  midpos1 = n//2-1
  midpos2 = n//2
  print(midpos1,midpos2)                         # Ans to Que A
  print(W[midpos1],W[midpos2])                   # Ans to Que B
  median = (W[midpos1]+ W[midpos2])/2            # And to Que C

  print("median of the dataset W is: ",median)

else:

  midpos = n//2
  print(midpos)                                   # Ans to Que A
  print(W[midpos])                                # Ans to Que B
  median = W[median]                              # And to Que C
  print("Median of the dataset  W is: ", median)

# %%
W = [21,41,51,61,81,91,101,221]
n=len(W)
if n%2 == 0:
    midpose1 = n//2-1
    midpose2 = n//2
    print(midpose1,midpose2)
    print(W[midpose1],W[midpose2])
    median=(W[midpose1]+W[midpose2])/2
    print("Median of the dataset W is: ", median)    
else:
    midpose = n//2
    print(midpose)                                   
    print(W[midpose])                               
    median = W[median]                            
    print("Median of the dataset W is: ", median)

# %%
V = [21,41,51,61,81,91,101,221,331,441,771,888]

n = len(V)
if n%2 == 0:
    midpose1 = n//2-1
    midpose2 =n//2
    median=(V[midpose1]+V[midpose2])/2
    print("median of the dataset: ", median)
# Out:
# median of the dataset:  96.0

# %%
W=[21,41,51,61,81,91,101,221,888]
n=len(W)
if n%2 == 0:
    midpose1 = n//2-1
    midpose2 = n//2
    median=(W[midpose1]+W[midpose2])/2
    print("dataset of median is:", median)

else:
    midpose1 = n//2
    median=W[midpose1]
    print("dataset median is:", median)
# Out:
# dataset median is: 81

# %%
x=[50,60,12,45,18,3,100,50,500,400,600,600,123,1546,1532]
